# %%
# Data given
raw_students = [
    {"name": "  ayesha SHARMA  ", "roll": "101", "marks_str": "88, 72, 95, 60, 78"},
    {"name": "ROHIT verma",       "roll": "102", "marks_str": "55, 68, 49, 72, 61"},
    {"name": "  Priya Nair  ",    "roll": "103", "marks_str": "91, 85, 88, 94, 79"},
    {"name": "karan MEHTA",       "roll": "104", "marks_str": "40, 55, 38, 62, 50"},
    {"name": " Sneha pillai ",    "roll": "105", "marks_str": "75, 80, 70, 68, 85"},
]

#Loop through each student
for stu in raw_students:

#Clean name
  clean_name = stu["name"].strip().title()
#Convert roll num
  roll_num =int(stu["roll"])
#Marks list
  marks_list = [int(x) for x in stu["marks_str"].split(", ")]

  is_valid = True
  for word in clean_name.split():
    if not word.isalpha():
      is_valid = False

  if is_valid:
    print("Valid name")
  else:
    print("Invalid name")

  print(f"students: {clean_name} | Roll: {roll_num} | Marks: {marks_list}")

  if roll_num == 103:
    print("UPPER:",clean_name.upper())
    print("LOWER:",clean_name.lower())

  print("----------------------")
# Out:
# Valid name
# students: Ayesha Sharma | Roll: 101 | Marks: [88, 72, 95, 60, 78]
# ----------------------
# Valid name
# students: Rohit Verma | Roll: 102 | Marks: [55, 68, 49, 72, 61]
# ----------------------
# Valid name
# students: Priya Nair | Roll: 103 | Marks: [91, 85, 88, 94, 79]
# UPPER: PRIYA NAIR
# LOWER: priya nair
# ----------------------
# Valid name
# students: Karan Mehta | Roll: 104 | Marks: [40, 55, 38, 62, 50]
# ----------------------
# Valid name
# students: Sneha Pillai | Roll: 105 | Marks: [75, 80, 70, 68, 85]
# ----------------------

# %%
# Subjects and marks
sub_list = ["Math", "Physics", "CS", "English", "Chemistry"]
marks_list = [88, 72, 95, 60, 78]

#Total marks
total = 0

for i in range(len(sub_list)):
  m = marks_list[i]

  if m >= 90:
    g = "A+"
  elif m >= 80:
    g = "A"
  elif m >= 70:
    g = "B"
  elif m >= 60:
    g = "C"
  else:
    g ="F"

  print(sub_list[i], m, g)
  total += m

avg = total / len(marks_list)

print("Total:", total)
print("Avg:", round(avg, 2))

# Highest and Lowest
high = max(marks_list)
low = min(marks_list)

print("Highest:",sub_list[marks_list.index(high)], high)
print("Lowest:",sub_list[marks_list.index(low)], low)
# Out:
# Math 88 A
# Physics 72 B
# CS 95 A+
# English 60 C
# Chemistry 78 B
# Total: 393
# Avg: 78.6
# Highest: CS 95
# Lowest: English 60

# %%
#New subjects
count = 0

while True:
  s = input("Enter subject (done to stop): ")

  if s == "done":
    break

  m = input("Enter marks: ")

  if not m.isdigit():
    print("Invalid")
    continue

  m = int(m)

  if m < 0 or m > 100:
    print("Invalid range")
    continue

  sub_list.append(s)
  marks_list.append(m)
  count += 1

print("Added:", count)
print("New Avg:", round(sum(marks_list)/len(marks_list), 2))
# Out:
# Enter subject (done to stop): Math2
# Enter marks: 85
# Enter subject (done to stop): done
# Added: 1
# New Avg: 79.67

# %%
# Calculating class performance

# Given class data
class_data = [
    ("Ayesha Sharma",  [88, 72, 95, 60, 78]),
    ("Rohit Verma",    [55, 68, 49, 72, 61]),
    ("Priya Nair",     [91, 85, 88, 94, 79]),
    ("Karan Mehta",    [40, 55, 38, 62, 50]),
    ("Sneha Pillai",   [75, 80, 70, 68, 85]),
]

# Variables to count pass and fail
pass_count = 0
fail_count = 0

# Variables for topper
top_name = ""
top_avg =0

# Variables to calculate class average
total_avg = 0

# heading
print("Name | Avg | Status")

# Loop through each student
for name, marks in class_data:

  # Calculate avereage marks
  avg = sum(marks) / len(marks)
  avg = round(avg, 2)

  # Check pass or fail
  if avg >= 60:
    status = "Pass"
    pass_count += 1
  else:
    status = "Fail"
    fail_count += 1

  #  Print student data
  print(name, "|", avg, "|", status)

  # Add to total average
  total_avg += avg

  # Check topper
  if avg > top_avg:
    top_avg = avg
    top_name = name

# Print pass and fail count
print("Passed:", pass_count)
print("Failed:", fail_count)

# Print topper
print("Topper:", top_name, "-", top_avg)

# Calculate and print clas average
class_avg = total_avg / len(class_data)
print("Class Avg:", round(class_avg, 2))
# Out:
# Name | Avg | Status
# Ayesha Sharma | 78.6 | Pass
# Rohit Verma | 61.0 | Pass
# Priya Nair | 87.4 | Pass
# Karan Mehta | 49.0 | Fail
# Sneha Pillai | 75.6 | Pass
# Passed: 4
# Failed: 1
# Topper: Priya Nair - 87.4
# Class Avg: 70.32

# %%
# Given essay
essay = "  python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.  "

# Step 1: Remove extra spaces
clean_essay = essay.strip()
print("Clean:", clean_essay)

# Step 2: Title case
print("Title:", clean_essay.title())

# Step 3: Count 'python'
count = clean_essay.count("python")
print("Count:", count)

# Step 4: Replace word
new_text = clean_essay.replace("python","Python 🐍")
print("Replaced:", new_text)

# Step 5: Split sentences
sentences = [s.strip()for s in clean_essay.split(". ")]
print("Sentences:", sentences)

# Step 6: Print numbered sentences
for i in range(len(sentences)):
    s = sentences[i]

    if not s.endswith("."):
      s = s + "."

    print(i+1, "-", s)
# Out:
# Clean: python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.
# Title: Python Is A Versatile Language. It Supports Object Oriented, Functional, And Procedural Programming. Python Is Widely Used In Data Science And Machine Learning.
# Count: 2
# Replaced: Python 🐍 is a versatile language. it supports object oriented, functional, and procedural programming. Python 🐍 is widely used in data science and machine learning.
# Sentences: ['python is a versatile language', 'it supports object oriented, functional, and procedural programming', 'python is widely used in data science and machine learning.']
# 1 - python is a versatile language.
# 2 - it supports object oriented, functional, and procedural programming.
# 3 - python is widely used in data science and machine learning.
